# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\setuptools\_importlib.py:23: UserWarning: `importlib-metadata` version is incompatible with `setuptools`.
# This problem is likely to be solved by installing an updated version of `importlib-metadata`.
#   warnings.warn(msg)  # Ensure a descriptive message is shown.

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('weatherAUS.csv')
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5     2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6     2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7     2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8     2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9     2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10    2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# 11    2008-12-12   Albury     15.9     21.7       2.2          NaN       NaN
# 12    2008-12-13   Albury     15.9     18.6      15.6          NaN       NaN
# 13    2008-12-14   Albury     12.6     21.0       3.6          NaN       NaN
# 14    2008-12-15   Albury      8.4     24.6       0.0          NaN       NaN
# 15    2008-12-16   Albury      9.8     27.7       NaN          NaN       NaN
# 16    2008-12-17   Albury     14.1     20.9       0.0          NaN       NaN
# 17    2008-12-18   Albury     13.5     22.9      16.8          NaN       NaN
# 18    2008-12-19   Albury     11.2     22.5      10.6          NaN       NaN
# 19    2008-12-20   Albury      9.8     25.6       0.0          NaN       NaN
# 20    2008-12-21   Albury     11.5     29.3       0.0          NaN       NaN
# 21    2008-12-22   Albury     17.1     33.0       0.0          NaN       NaN
# 22    2008-12-23   Albury     20.5     31.8       0.0          NaN       NaN
# 23    2008-12-24   Albury     15.3     30.9       0.0          NaN       NaN
# 24    2008-12-25   Albury     12.6     32.4       0.0          NaN       NaN
# 25    2008-12-26   Albury     16.2     33.9       0.0          NaN       NaN
# 26    2008-12-27   Albury     16.9     33.0       0.0          NaN       NaN
# 27    2008-12-28   Albury     20.1     32.7       0.0          NaN       NaN
# 28    2008-12-29   Albury     19.7     27.2       0.0          NaN       NaN
# 29    2008-12-30   Albury     12.5     24.2       1.2          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8395  2017-05-27    Uluru      9.3     28.0       0.0          NaN       NaN
# 8396  2017-05-28    Uluru      8.0     24.6       0.0          NaN       NaN
# 8397  2017-05-29    Uluru     12.7     22.2       0.0          NaN       NaN
# 8398  2017-05-30    Uluru      9.4     22.7       0.0          NaN       NaN
# 8399  2017-05-31    Uluru      5.4     20.5       0.0          NaN       NaN
# 8400  2017-06-01    Uluru      5.6     19.4       0.0          NaN       NaN
# 8401  2017-06-02    Uluru      1.5     19.2       0.0          NaN       NaN
# 8402  2017-06-03    Uluru      3.8     19.8       0.0          NaN       NaN
# 8403  2017-06-04    Uluru      4.5     18.8       0.0          NaN       NaN
# 8404  2017-06-05    Uluru      4.9     20.7       0.0          NaN       NaN
# 8405  2017-06-06    Uluru      1.2     20.8       0.0          NaN       NaN
# 8406  2017-06-07    Uluru      0.5     21.7       0.0          NaN       NaN
# 8407  2017-06-08    Uluru      4.0     20.0       0.0          NaN       NaN
# 8408  2017-06-09    Uluru      3.4     19.8       0.0          NaN       NaN
# 8409  2017-06-10    Uluru      3.2     18.6       0.0          NaN       NaN
# 8410  2017-06-11    Uluru      2.4     19.1       0.0          NaN       NaN
# 8411  2017-06-12    Uluru      5.1     19.7       0.0          NaN       NaN
# 8412  2017-06-13    Uluru      2.5     21.2       0.0          NaN       NaN
# 8413  2017-06-14    Uluru      2.3     21.4       0.0          NaN       NaN
# 8414  2017-06-15    Uluru      2.6     22.5       0.0          NaN       NaN
# 8415  2017-06-16    Uluru      5.2     24.3       0.0          NaN       NaN
# 8416  2017-06-17    Uluru      6.4     23.4       0.0          NaN       NaN
# 8417  2017-06-18    Uluru      8.0     20.7       0.0          NaN       NaN
# 8418  2017-06-19    Uluru      7.4     20.6       0.0          NaN       NaN
# 8419  2017-06-20    Uluru      3.5     21.8       0.0          NaN       NaN
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0              W           44.0          W  ...        71.0         22.0
# 1            WNW           44.0        NNW  ...        44.0         25.0
# 2            WSW           46.0          W  ...        38.0         30.0
# 3             NE           24.0         SE  ...        45.0         16.0
# 4              W           41.0        ENE  ...        82.0         33.0
# 5            WNW           56.0          W  ...        55.0         23.0
# 6              W           50.0         SW  ...        49.0         19.0
# 7              W           35.0        SSE  ...        48.0         19.0
# 8            NNW           80.0         SE  ...        42.0          9.0
# 9              W           28.0          S  ...        58.0         27.0
# 10             N           30.0        SSE  ...        48.0         22.0
# 11           NNE           31.0         NE  ...        89.0         91.0
# 12             W           61.0        NNW  ...        76.0         93.0
# 13            SW           44.0          W  ...        65.0         43.0
# 14           NaN            NaN          S  ...        57.0         32.0
# 15           WNW           50.0        NaN  ...        50.0         28.0
# 16           ENE           22.0        SSW  ...        69.0         82.0
# 17             W           63.0          N  ...        80.0         65.0
# 18           SSE           43.0        WSW  ...        47.0         32.0
# 19           SSE           26.0         SE  ...        45.0         26.0
# 20             S           24.0         SE  ...        56.0         28.0
# 21            NE           43.0         NE  ...        38.0         28.0
# 22           WNW           41.0          W  ...        54.0         24.0
# 23             N           33.0        ESE  ...        55.0         23.0
# 24             W           43.0          E  ...        49.0         17.0
# 25           WSW           35.0         SE  ...        45.0         19.0
# 26           WSW           57.0        NaN  ...        41.0         28.0
# 27           WNW           48.0          N  ...        56.0         15.0
# 28           WNW           46.0         NW  ...        49.0         22.0
# 29           WNW           50.0        WSW  ...        78.0         70.0
# ...          ...            ...        ...  ...         ...          ...
# 8395           W           28.0        SSW  ...        36.0         16.0
# 8396           E           33.0         SE  ...        46.0         25.0
# 8397           E           37.0          E  ...        59.0         34.0
# 8398           E           35.0         SE  ...        62.0         32.0
# 8399           E           46.0          E  ...        56.0         32.0
# 8400           E           43.0          E  ...        61.0         22.0
# 8401           E           37.0        ESE  ...        45.0         18.0
# 8402         ENE           39.0        ESE  ...        42.0         22.0
# 8403           E           31.0        ESE  ...        42.0         26.0
# 8404           E           37.0        ESE  ...        38.0         11.0
# 8405           E           43.0        ESE  ...        29.0          6.0
# 8406           E           43.0        ESE  ...        27.0         19.0
# 8407          SE           39.0        ESE  ...        58.0         26.0
# 8408           E           43.0        ESE  ...        54.0         23.0
# 8409           E           46.0        ESE  ...        56.0         29.0
# 8410           E           33.0         SE  ...        59.0         24.0
# 8411           E           46.0        ESE  ...        56.0         29.0
# 8412         ENE           35.0        ESE  ...        57.0         32.0
# 8413          SE           22.0         SE  ...        60.0         28.0
# 8414           S           19.0          S  ...        59.0         24.0
# 8415           E           24.0         SE  ...        53.0         24.0
# 8416         ESE           31.0          S  ...        53.0         25.0
# 8417         ESE           41.0         SE  ...        56.0         32.0
# 8418           E           35.0        ESE  ...        63.0         33.0
# 8419           E           31.0        ESE  ...        59.0         27.0
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1007.7       1007.1       8.0       NaN     16.9     21.8
# 1          1010.6       1007.8       NaN       NaN     17.2     24.3
# 2          1007.6       1008.7       NaN       2.0     21.0     23.2
# 3          1017.6       1012.8       NaN       NaN     18.1     26.5
# 4          1010.8       1006.0       7.0       8.0     17.8     29.7
# 5          1009.2       1005.4       NaN       NaN     20.6     28.9
# 6          1009.6       1008.2       1.0       NaN     18.1     24.6
# 7          1013.4       1010.1       NaN       NaN     16.3     25.5
# 8          1008.9       1003.6       NaN       NaN     18.3     30.2
# 9          1007.0       1005.7       NaN       NaN     20.1     28.2
# 10         1011.8       1008.7       NaN       NaN     20.4     28.8
# 11         1010.5       1004.2       8.0       8.0     15.9     17.0
# 12          994.3        993.0       8.0       8.0     17.4     15.8
# 13         1001.2       1001.8       NaN       7.0     15.8     19.8
# 14         1009.7       1008.7       NaN       NaN     15.9     23.5
# 15         1013.4       1010.3       0.0       NaN     17.3     26.2
# 16         1012.2       1010.4       8.0       1.0     17.2     18.1
# 17         1005.8       1002.2       8.0       1.0     18.0     21.5
# 18         1009.4       1009.7       NaN       2.0     15.5     21.0
# 19         1019.2       1017.1       NaN       NaN     15.8     23.2
# 20         1019.3       1014.8       NaN       NaN     19.1     27.3
# 21         1013.6       1008.1       NaN       1.0     24.5     31.6
# 22         1007.8       1005.7       NaN       NaN     23.8     30.8
# 23         1011.0       1008.2       5.0       NaN     20.9     29.0
# 24         1012.9       1010.1       NaN       NaN     21.5     31.2
# 25         1010.9       1007.6       NaN       1.0     23.2     33.0
# 26         1006.8       1003.6       NaN       1.0     26.6     31.2
# 27         1005.2       1001.7       NaN       NaN     24.6     32.1
# 28         1004.8       1004.2       NaN       NaN     21.6     26.1
# 29         1005.6       1003.4       8.0       8.0     12.5     18.2
# ...           ...          ...       ...       ...      ...      ...
# 8395       1019.9       1016.9       NaN       NaN     16.6     27.3
# 8396       1021.7       1018.8       4.0       NaN     13.8     23.5
# 8397       1024.3       1021.7       8.0       8.0     13.9     21.0
# 8398       1026.6       1023.6       8.0       4.0     11.8     22.3
# 8399       1029.2       1025.3       NaN       NaN     11.1     20.2
# 8400       1029.6       1027.1       NaN       NaN      9.7     18.3
# 8401       1030.7       1026.7       NaN       NaN      6.8     17.6
# 8402       1028.7       1024.1       NaN       NaN      8.6     18.9
# 8403       1026.9       1022.4       NaN       NaN      9.5     18.6
# 8404       1027.1       1023.9       NaN       NaN     10.3     19.8
# 8405       1029.8       1025.9       NaN       NaN      7.9     19.9
# 8406       1029.0       1025.0       NaN       NaN      9.5     20.5
# 8407       1030.2       1026.7       NaN       NaN      9.1     19.0
# 8408       1031.8       1027.7       NaN       NaN      8.7     18.9
# 8409       1031.0       1027.2       NaN       NaN      8.2     17.4
# 8410       1030.0       1026.2       NaN       NaN      8.0     18.8
# 8411       1028.5       1025.8       NaN       NaN      8.5     19.2
# 8412       1027.2       1023.0       NaN       NaN     10.3     20.3
# 8413       1026.9       1022.8       NaN       NaN      8.9     20.3
# 8414       1025.0       1021.4       NaN       NaN      8.8     22.1
# 8415       1023.8       1020.0       NaN       NaN     12.3     23.3
# 8416       1025.8       1023.0       NaN       NaN     11.2     23.1
# 8417       1028.1       1024.3       NaN       7.0     11.6     20.0
# 8418       1027.2       1023.3       NaN       NaN     11.0     20.3
# 8419       1024.7       1021.2       NaN       NaN      9.4     20.9
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 0            No            No
# 1            No            No
# 2            No            No
# 3            No            No
# 4            No            No
# 5            No            No
# 6            No            No
# 7            No            No
# 8            No           Yes
# 9           Yes            No
# 10           No           Yes
# 11          Yes           Yes
# 12          Yes           Yes
# 13          Yes            No
# 14           No           NaN
# 15          NaN            No
# 16           No           Yes
# 17          Yes           Yes
# 18          Yes            No
# 19           No            No
# 20           No            No
# 21           No            No
# 22           No            No
# 23           No            No
# 24           No            No
# 25           No            No
# 26           No            No
# 27           No            No
# 28           No           Yes
# 29          Yes            No
# ...         ...           ...
# 8395         No            No
# 8396         No            No
# 8397         No            No
# 8398         No            No
# 8399         No            No
# 8400         No            No
# 8401         No            No
# 8402         No            No
# 8403         No            No
# 8404         No            No
# 8405         No            No
# 8406         No            No
# 8407         No            No
# 8408         No            No
# 8409         No            No
# 8410         No            No
# 8411         No            No
# 8412         No            No
# 8413         No            No
# 8414         No            No
# 8415         No            No
# 8416         No            No
# 8417         No            No
# 8418         No            No
# 8419         No            No
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [8425 rows x 23 columns]

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [5 rows x 23 columns]

# %%
#df.set_index('Date', inplace=True)

# %% [markdown]
# # Remove Unwanted Columns

# %%
df.drop(['Evaporation','Sunshine'], axis=1, inplace=True)

# %%
# convert the date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm',
#        'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 21 columns):
# Date             8425 non-null datetime64[ns]
# Location         8425 non-null object
# MinTemp          8425 non-null float64
# MaxTemp          8425 non-null float64
# Rainfall         8425 non-null float64
# WindGustDir      8425 non-null object
# WindGustSpeed    8425 non-null float64
# WindDir9am       8425 non-null object
# WindDir3pm       8425 non-null object
# WindSpeed9am     8425 non-null float64
# WindSpeed3pm     8425 non-null float64
# Humidity9am      8425 non-null float64
# Humidity3pm      8425 non-null float64
# Pressure9am      8425 non-null float64
# Pressure3pm      8425 non-null float64
# Cloud9am         8425 non-null float64
# Cloud3pm         8423 non-null float64
# Temp9am          8425 non-null float64
# Temp3pm          8425 non-null float64
# RainToday        8425 non-null int32
# RainTomorrow     8425 non-null int32
# dtypes: datetime64[ns](1), float64(14), int32(2), object(4)
# memory usage: 1.3+ MB

# %%
df.describe().round(4)
# Out:
#          MinTemp    MaxTemp   Rainfall  WindGustSpeed  WindSpeed9am  \
# count  8425.0000  8425.0000  8425.0000      8425.0000     8425.0000
# mean     13.1909    23.8639     2.8044        41.4945       13.7973
# std       5.4013     6.1299    10.3851        14.4842       10.1776
# min      -2.0000     8.2000     0.0000         7.0000        0.0000
# 25%       9.2000    19.3000     0.0000        31.0000        6.0000
# 50%      13.3000    23.3000     0.0000        41.0000       13.0000
# 75%      17.4000    28.0000     1.0000        52.0000       20.0000
# max      28.5000    45.5000   371.0000       107.0000       63.0000
#
#        WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# count     8425.0000    8425.0000    8425.0000    8425.0000    8425.0000
# mean        18.6317      67.8761      51.2062    1018.7215    1015.9917
# std          9.9185      16.8355      18.4682       6.7648       6.4621
# min          0.0000      10.0000       6.0000     989.8000     982.9000
# 25%         11.0000      56.0000      39.0000    1014.0000    1011.4000
# 50%         19.0000      68.0000      51.0000    1019.3000    1016.9000
# 75%         26.0000      80.0000      63.0000    1024.6000    1020.1000
# max         83.0000     100.0000      99.0000    1039.0000    1036.0000
#
#         Cloud9am   Cloud3pm    Temp9am    Temp3pm  RainToday  RainTomorrow
# count  8425.0000  8423.0000  8425.0000  8425.0000  8425.0000     8425.0000
# mean      4.6646     4.4111    17.7626    22.4553     0.2434        0.2436
# std       3.0132     2.7722     5.6243     5.9616     0.4292        0.4293
# min       0.0000     0.0000     1.9000     7.3000     0.0000        0.0000
# 25%       1.0000     1.0000    13.8000    18.1000     0.0000        0.0000
# 50%       6.0000     5.0000    17.8000    21.9000     0.0000        0.0000
# 75%       7.0000     7.0000    21.9000    26.4000     0.0000        0.0000
# max       8.0000     8.0000    39.4000    44.1000     1.0000        1.0000

# %%
df.shape
# Out:
# (8425, 21)

# %%
df.duplicated().sum()
# Out:
# 1663

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         2
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# # Fill the NaN rows

# %%
#for column in df.columns:
  #  df[column].fillna(method='ffill', inplace=True)

# %%
# fill NaN values with the mean of the column
df.fillna(df.mean(), inplace=True)

# print the DataFram
print(df)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  WindGustDir  \
# 0    2008-12-01         1     13.4     22.9       0.6           13
# 1    2008-12-02         1      7.4     25.1       0.0           14
# 2    2008-12-03         1     12.9     25.7       0.0           15
# 3    2008-12-04         1      9.2     28.0       0.0            4
# 4    2008-12-05         1     17.5     32.3       1.0           13
# 5    2008-12-06         1     14.6     29.7       0.2           14
# 6    2008-12-07         1     14.3     25.0       0.0           13
# 7    2008-12-08         1      7.7     26.7       0.0           13
# 8    2008-12-09         1      9.7     31.9       0.0            6
# 9    2008-12-10         1     13.1     30.1       1.4           13
# 10   2008-12-11         1     13.4     30.4       0.0            3
# 11   2008-12-12         1     15.9     21.7       2.2            5
# 12   2008-12-13         1     15.9     18.6      15.6           13
# 13   2008-12-14         1     12.6     21.0       3.6           12
# 14   2008-12-15         1      8.4     24.6       0.0           12
# 15   2008-12-16         1      9.8     27.7       0.0           14
# 16   2008-12-17         1     14.1     20.9       0.0            1
# 17   2008-12-18         1     13.5     22.9      16.8           13
# 18   2008-12-19         1     11.2     22.5      10.6           10
# 19   2008-12-20         1      9.8     25.6       0.0           10
# 20   2008-12-21         1     11.5     29.3       0.0            8
# 21   2008-12-22         1     17.1     33.0       0.0            4
# 22   2008-12-23         1     20.5     31.8       0.0           14
# 23   2008-12-24         1     15.3     30.9       0.0            3
# 24   2008-12-25         1     12.6     32.4       0.0           13
# 25   2008-12-26         1     16.2     33.9       0.0           15
# 26   2008-12-27         1     16.9     33.0       0.0           15
# 27   2008-12-28         1     20.1     32.7       0.0           14
# 28   2008-12-29         1     19.7     27.2       0.0           14
# 29   2008-12-30         1     12.5     24.2       1.2           14
# ...         ...       ...      ...      ...       ...          ...
# 8395 2017-05-27         9      9.3     28.0       0.0           13
# 8396 2017-05-28         9      8.0     24.6       0.0            0
# 8397 2017-05-29         9     12.7     22.2       0.0            0
# 8398 2017-05-30         9      9.4     22.7       0.0            0
# 8399 2017-05-31         9      5.4     20.5       0.0            0
# 8400 2017-06-01         9      5.6     19.4       0.0            0
# 8401 2017-06-02         9      1.5     19.2       0.0            0
# 8402 2017-06-03         9      3.8     19.8       0.0            1
# 8403 2017-06-04         9      4.5     18.8       0.0            0
# 8404 2017-06-05         9      4.9     20.7       0.0            0
# 8405 2017-06-06         9      1.2     20.8       0.0            0
# 8406 2017-06-07         9      0.5     21.7       0.0            0
# 8407 2017-06-08         9      4.0     20.0       0.0            9
# 8408 2017-06-09         9      3.4     19.8       0.0            0
# 8409 2017-06-10         9      3.2     18.6       0.0            0
# 8410 2017-06-11         9      2.4     19.1       0.0            0
# 8411 2017-06-12         9      5.1     19.7       0.0            0
# 8412 2017-06-13         9      2.5     21.2       0.0            1
# 8413 2017-06-14         9      2.3     21.4       0.0            9
# 8414 2017-06-15         9      2.6     22.5       0.0            8
# 8415 2017-06-16         9      5.2     24.3       0.0            0
# 8416 2017-06-17         9      6.4     23.4       0.0            2
# 8417 2017-06-18         9      8.0     20.7       0.0            2
# 8418 2017-06-19         9      7.4     20.6       0.0            0
# 8419 2017-06-20         9      3.5     21.8       0.0            0
# 8420 2017-06-21         9      2.8     23.4       0.0            0
# 8421 2017-06-22         9      3.6     25.3       0.0            6
# 8422 2017-06-23         9      5.4     26.9       0.0            3
# 8423 2017-06-24         9      7.8     27.0       0.0            9
# 8424 2017-06-25         9     14.9     27.0       0.0            9
#
#       WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0              44.0          13          14          20.0  ...         71.0
# 1              44.0           6          15           4.0  ...         44.0
# 2              46.0          13          15          19.0  ...         38.0
# 3              24.0           9           0          11.0  ...         45.0
# 4              41.0           1           7           7.0  ...         82.0
# 5              56.0          13          13          19.0  ...         55.0
# 6              50.0          12          13          20.0  ...         49.0
# 7              35.0          10          13           6.0  ...         48.0
# 8              80.0           9           7           7.0  ...         42.0
# 9              28.0           8          10          15.0  ...         58.0
# 10             30.0          10           2          17.0  ...         48.0
# 11             31.0           4           1          15.0  ...         89.0
# 12             61.0           6           6          28.0  ...         76.0
# 13             44.0          13          11          24.0  ...         65.0
# 14             44.0           8          14           4.0  ...         57.0
# 15             50.0           8          14           4.0  ...         50.0
# 16             22.0          11           0          11.0  ...         69.0
# 17             63.0           3          14           6.0  ...         80.0
# 18             43.0          15          12          24.0  ...         47.0
# 19             26.0           9           6          17.0  ...         45.0
# 20             24.0           9           9           9.0  ...         56.0
# 21             43.0           4           3          17.0  ...         38.0
# 22             41.0          13          13          19.0  ...         54.0
# 23             33.0           2           7           6.0  ...         55.0
# 24             43.0           0          13           4.0  ...         49.0
# 25             35.0           9          15           9.0  ...         45.0
# 26             57.0           9          13           0.0  ...         41.0
# 27             48.0           3          14          13.0  ...         56.0
# 28             46.0           7          15          19.0  ...         49.0
# 29             50.0          15          12          11.0  ...         78.0
# ...             ...         ...         ...           ...  ...          ...
# 8395           28.0          11          14           6.0  ...         36.0
# 8396           33.0           9           2          11.0  ...         46.0
# 8397           37.0           0           2          19.0  ...         59.0
# 8398           35.0           9           0          13.0  ...         62.0
# 8399           46.0           0           0          20.0  ...         56.0
# 8400           43.0           0           2          22.0  ...         61.0
# 8401           37.0           2           2          17.0  ...         45.0
# 8402           39.0           2           0          19.0  ...         42.0
# 8403           31.0           2           0          13.0  ...         42.0
# 8404           37.0           2           2          17.0  ...         38.0
# 8405           43.0           2           0          13.0  ...         29.0
# 8406           43.0           2           1          13.0  ...         27.0
# 8407           39.0           2           2          13.0  ...         58.0
# 8408           43.0           2           0          19.0  ...         54.0
# 8409           46.0           2           0          15.0  ...         56.0
# 8410           33.0           9           0          17.0  ...         59.0
# 8411           46.0           2           0          13.0  ...         56.0
# 8412           35.0           2           0          17.0  ...         57.0
# 8413           22.0           9          10          11.0  ...         60.0
# 8414           19.0           8           0           9.0  ...         59.0
# 8415           24.0           9           0          11.0  ...         53.0
# 8416           31.0           8           2          15.0  ...         53.0
# 8417           41.0           9           0          19.0  ...         56.0
# 8418           35.0           2           0          15.0  ...         63.0
# 8419           31.0           2           0          15.0  ...         59.0
# 8420           31.0           9           1          13.0  ...         51.0
# 8421           22.0           9           3          13.0  ...         56.0
# 8422           37.0           9          14           9.0  ...         53.0
# 8423           28.0          10           3          13.0  ...         51.0
# 8424           28.0           2           2          17.0  ...         62.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 
#
#       WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0              44.0          13          14          20.0  ...         71.0
# 1              44.0           6          15           4.0  ...         44.0
# 2              46.0          13          15          19.0  ...         38.0
# 3              24.0           9           0          11.0  ...         45.0
# 4              41.0           1           7           7.0  ...         82.0
# 5              56.0          13          13          19.0  ...         55.0
# 6              50.0          12          13          20.0  ...         49.0
# 7              35.0          10          13           6.0  ...         48.0
# 8              80.0           9           7           7.0  ...         42.0
# 9              28.0           8          10          15.0  ...         58.0
# 10             30.0          10           2          17.0  ...         48.0
# 11             31.0           4           1          15.0  ...         89.0
# 12             61.0           6           6          28.0  ...         76.0
# 13             44.0          13          11          24.0  ...         65.0
# 14             44.0           8          14           4.0  ...         57.0
# 15             50.0           8          14           4.0  ...         50.0
# 16             22.0          11           0          11.0  ...         69.0
# 17             63.0           3          14           6.0  ...         80.0
# 18             43.0          15          12          24.0  ...         47.0
# 19             26.0           9           6          17.0  ...         45.0
# 20             24.0           9           9           9.0  ...         56.0
# 21             43.0           4           3          17.0  ...         38.0
# 22             41.0          13          13          19.0  ...         54.0
# 23             33.0           2           7           6.0  ...         55.0
# 24             43.0           0          13           4.0  ...         49.0
# 25             35.0           9          15           9.0  ...         45.0
# 26             57.0           9          13           0.0  ...         41.0
# 27             48.0           3          14          13.0  ...         56.0
# 28             46.0           7          15          19.0  ...         49.0
# 29             50.0          15          12          11.0  ...         78.0
# ...             ...         ...         ...           ...  ...          ...
# 8395           28.0          11          14           6.0  ...         36.0
# 8396           33.0           9           2          11.0  ...         46.0
# 8397           37.0           0           2          19.0  ...         59.0
# 8398           35.0           9           0          13.0  ...         62.0
# 8399           46.0           0           0          20.0  ...         56.0
# 8400           43.0           0           2          22.0  ...         61.0
# 8401           37.0           2           2          17.0  ...         45.0
# 8402           39.0           2           0          19.0  ...         42.0
# 8403           31.0           2           0          13.0  ...         42.0
# 8404           37.0           2           2          17.0  ...         38.0
# 8405           43.0           2           0          13.0  ...         29.0
# 8406           43.0           2           1          13.0  ...         27.0
# 8407           39.0           2           2          13.0  ...         58.0
# 8408           43.0           2           0          19.0  ...         54.0
# 8409           46.0           2           0          15.0  ...         56.0
# 8410           33.0           9           0          17.0  ...         59.0
# 8411           46.0           2           0          13.0  ...         56.0
# 8412           35.0           2           0          17.0  ...         57.0
# 8413           22.0           9          10          11.0  ...         60.0
# 8414           19.0           8           0           9.0  ...         59.0
# 8415           24.0           9           0          11.0  ...         53.0
# 8416           31.0           8           2          15.0  ...         53.0
# 8417           41.0           9           0          19.0  ...         56.0
# 8418           35.0           2           0          15.0  ...         63.0
# 8419           31.0           2           0          15.0  ...         59.0
# 8420           31.0           9           1          13.0  ...         51.0
# 8421           22.0           9           3          13.0  ...         56.0
# 8422           37.0           9          14           9.0  ...         53.0
# 8423           28.0          10           3          13.0  ...         51.0
# 8424           28.0           2           2          17.0  ...         62.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 
# 8417         32.0       1028.1       1024.3       8.0  7.000000     11.6
# 8418         33.0       1027.2       1023.3       8.0  7.000000     11.0
# 8419         27.0       1024.7       1021.2       8.0  7.000000      9.4
# 8420         24.0       1024.6       1020.3       8.0  7.000000     10.1
# 8421         21.0       1023.5       1019.1       8.0  7.000000     10.9
# 8422         24.0       1021.0       1016.8       8.0  7.000000     12.5
# 8423         24.0       1019.4       1016.5       3.0  2.000000     15.1
# 8424         36.0       1020.2       1017.9       8.0  8.000000     15.0
#
#       Temp3pm  RainToday  RainTomorrow
# 0        21.8          0             0
# 1        24.3          0             0
# 2        23.2          0             0
# 3        26.5          0             0
# 4        29.7          0             0
# 5        28.9          0             0
# 6        24.6          0             0
# 7        25.5          0             0
# 8        30.2          0             1
# 9        28.2          1             0
# 10       28.8          0             1
# 11       17.0          1             1
# 12       15.8          1             1
# 13       19.8          1             0
# 14       23.5          0             0
# 15       26.2          0             0
# 16       18.1          0             1
# 17       21.5          1             1
# 18       21.0          1             0
# 19       23.2          0             0
# 20       27.3          0             0
# 21       31.6          0             0
# 22       30.8          0             0
# 23       29.0          0             0
# 24       31.2          0             0
# 25       33.0          0             0
# 26       31.2          0             0
# 27       32.1          0             0
# 28       26.1          0             1
# 29       18.2          1             0
# ...       ...        ...           ...
# 8395     27.3          0             0
# 8396     23.5          0             0
# 8397     21.0          0             0
# 8398     22.3          0             0
# 8399     20.2          0             0
# 8400     18.3          0             0
# 8401     17.6          0             0
# 8402     18.9          0             0
# 8403     18.6          0             0
# 8404     19.8          0             0
# 8405     19.9          0             0
# 8406     20.5          0             0
# 8407     19.0          0             0
# 8408     18.9          0             0
# 8409     17.4          0             0
# 8410     18.8          0             0
# 8411     19.2          0             0
# 8412     20.3          0             0
# 8413     20.3          0             0
# 8414     22.1          0             0
# 8415     23.3          0             0
# 8416     23.1          0             0
# 8417     20.0          0             0
# 8418     20.3          0             0
# 8419     20.9          0             0
# 8420     22.4          0             0
# 8421     24.5          0             0
# 8422     26.1          0             0
# 8423     26.0          0             0
# 8424     20.9          0             0
#
# [8425 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 21 columns):
# Date             8425 non-null datetime64[ns]
# Location         8425 non-null int64
# MinTemp          8425 non-null float64
# MaxTemp          8425 non-null float64
# Rainfall         8425 non-null float64
# WindGustDir      8425 non-null int64
# WindGustSpeed    8425 non-null float64
# WindDir9am       8425 non-null int64
# WindDir3pm       8425 non-null int64
# WindSpeed9am     8425 non-null float64
# WindSpeed3pm     8425 non-null float64
# Humidity9am      8425 non-null float64
# Humidity3pm      8425 non-null float64
# Pressure9am      8425 non-null float64
# Pressure3pm      8425 non-null float64
# Cloud9am         8425 non-null float64
# Cloud3pm         8425 non-null float64
# Temp9am          8425 non-null float64
# Temp3pm          8425 non-null float64
# RainToday        8425 non-null int64
# RainTomorrow     8425 non-null int64
# dtypes: datetime64[ns](1), float64(14), int64(6)
# memory usage: 1.3 MB

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm',
#        'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 1663

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.corr()
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  WindGustDir  \
# Location       1.000000  0.115105  0.063072  0.006624    -0.021383
# MinTemp        0.115105  1.000000  0.720788  0.087559    -0.155337
# MaxTemp        0.063072  0.720788  1.000000 -0.087806    -0.233530
# Rainfall       0.006624  0.087559 -0.087806  1.000000     0.033716
# WindGustDir   -0.021383 -0.155337 -0.233530  0.033716     1.000000
# WindGustSpeed  0.239117  0.217405  0.133485  0.095290    -0.026615
# WindDir9am    -0.038067 -0.084434 -0.246292  0.093485     0.386321
# WindDir3pm    -0.028875 -0.153255 -0.184062  0.036233     0.519730
# WindSpeed9am   0.221625  0.136321  0.012511  0.047320     0.000952
# WindSpeed3pm   0.228682  0.164055  0.079787  0.023039     0.071324
# Humidity9am    0.005934 -0.130364 -0.389909  0.231710     0.043536
# Humidity3pm    0.055239  0.086055 -0.412943  0.238901     0.062353
# Pressure9am   -0.000190 -0.421642 -0.308910 -0.059682    -0.164608
# Pressure3pm    0.001084 -0.422942 -0.392053 -0.026309    -0.072135
# Cloud9am      -0.002209  0.052310 -0.236134  0.133703     0.122252
# Cloud3pm      -0.023631  0.051632 -0.206845  0.135449     0.091086
# Temp9am        0.116392  0.888412  0.868379 -0.007316    -0.183927
# Temp3pm        0.059913  0.684419  0.973421 -0.091329    -0.248577
# RainToday      0.003266  0.063675 -0.228006  0.465729     0.124925
# RainTomorrow   0.003021  0.094144 -0.159352  0.230010     0.051130
#
#                WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# Location            0.239117   -0.038067   -0.028875      0.221625
# MinTemp             0.217405   -0.084434   -0.153255      0.136321
# MaxTemp             0.133485   -0.246292   -0.184062      0.012511
# Rainfall            0.095290    0.093485    0.036233      0.047320
# WindGustDir        -0.026615    0.386321    0.519730      0.000952
# WindGustSpeed       1.000000   -0.107290    0.073966      0.512668
# WindDir9am         -0.107290    1.000000    0.258568     -0.063289
# WindDir3pm          0.073966    0.258568    1.000000      0.027731
# WindSpeed9am        0.512668   -0.063289    0.027731      1.000000
# WindSpeed3pm        0.562793   -0.031284    0.088925      0.541638
# Humidity9am        -0.233198    0.101256   -0.013646     -0.359573
# Humidity3pm        -0.068580    0.159716   -0.022770     -0.110249
# Pressure9am        -0.336246    0.007634   -0.123141     -0.295491
# Pressure3pm        -0.326681    0.088375   -0.039744     -0.231156
# Cloud9am            0.047649    0.103719    0.080231      0.069009
# Cloud3pm            0.113525    0.082977    0.057818      0.120169
# Temp9am             0.191361   -0.152085   -0.169439      0.109048
# Temp3pm             0.098229   -0.252479   -0.191952     -0.004340
# RainToday           0.078004    0.161201    0.098166      0.037308
# RainTomorrow        0.183470    0.037962    0.011335      0.067821
#
#                WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# Location           0.228682     0.005934     0.055239    -0.000190
# MinTemp            0.164055    -0.130364     0.086055    -0.421642
# MaxTemp            0.079787    -0.389909    -0.412943    -0.308910
# Rainfall           0.023039     0.231710     0.238901    -0.059682
# WindGustDir        0.071324     0.043536     0.062353    -0.164608
# WindGustSpeed      0.562793    -0.233198    -0.068580    -0.336246
# WindDir9am        -0.031284     0.101256     0.159716     0.007634
# WindDir3pm         0.088925    -0.013646    -0.022770    -0.123141
# WindSpeed9am       0.541638    -0.359573    -0.110249    -0.295491
# WindSpeed3pm       1.000000    -0.244188    -0.108201    -0.324207
# Humidity9am       -0.244188     1.000000     0.628570     0.187599
# Humidity3pm       -0.108201     0.628570     1.000000     0.007487
# Pressure9am       -0.324207     0.187599     0.007487     1.000000
# Pressure3pm       -0.265197     0.206430     0.071431     0.960235
# Cloud9am           0.070376     0.293400     0.363403    -0.128319
# Cloud3pm           0.055773     0.226943     0.384539    -0.140657
# Temp9am            0.171585    -0.377419    -0.122888    -0.408549
# Temp3pm            0.073545    -0.379539    -0.491407    -0.265213
# RainToday          0.021735     0.378328     0.362195    -0.089127
# RainTomorrow       0.052997     0.283456     0.451617    -0.148753
#
#                Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  \
# Location          0.001084 -0.002209 -0.023631  0.116392  0.059913   0.003266
# MinTemp          -0.422942  0.052310  0.051632  0.888412  0.684419   0.063675
# MaxTemp          -0.392053 -0.236134 -0.206845  0.868379  0.973421  -0.228006
# Rainfall         -0.026309  0.133703  0.135449 -0.007316 -0.091329   0.465729
# WindGustDir      -0.072135  0.122252  0.091086 -0.183927 -0.248577   0.124925
# WindGustSpeed    -0.326681  0.047649  0.113525  0.191361  0.098229   0.078004
# WindDir9am        0.088375  0.103719  0.082977 -0.152085 -0.252479   0.161201
# WindDir3pm       -0.039744  0.080231  0.057818 -0.169439 -0.191952   0.098166
# WindSpeed9am     -0.231156  0.069009  0.120169  0.109048 -0.004340   0.037308
# WindSpeed3pm     -0.265197  0.070376  0.055773  0.171585  0.073545   0.021735
# Humidity9am       0.206430  0.293400  0.226943 -0.377419 -0.379539   0.378328
# Humidity3pm       0.071431  0.363403  0.384539 -0.122888 -0.491407   0.362195
# Pressure9am       0.960235 -0.128319 -0.140657 -0.408549 -0.265213  -0.089127
# Pressure3pm       1.000000 -0.054245 -0.075950 -0.441593 -0.356674  -0.024828
# Cloud9am         -0.054245  1.000000  0.514712 -0.119751 -0.249742   0.206437
# Cloud3pm         -0.075950  0.514712  1.000000 -0.088771 -0.248401   0.221496
# Temp9am          -0.441593 -0.119751 -0.088771  1.000000  0.832248  -0.101835
# Temp3pm          -0.356674 -0.249742 -0.248401  0.832248  1.000000  -0.238487
# RainToday        -0.024828  0.206437  0.221496 -0.101835 -0.238487   1.000000
# RainTomorrow     -0.125324  0.202671  0.293250 -0.028347 -0.200515   0.340510
#
#                RainTomorrow
# Location           0.003021
# MinTemp            0.094144
# MaxTemp           -0.159352
# Rainfall           0.230010
# WindGustDir        0.051130
# WindGustSpeed      0.183470
# WindDir9am         0.037962
# WindDir3pm         0.011335
# WindSpeed9am       0.067821
# WindSpeed3pm       0.052997
# Humidity9am        0.283456
# Humidity3pm        0.451617
# Pressure9am       -0.148753
# Pressure3pm       -0.125324
# Cloud9am           0.202671
# Cloud3pm           0.293250
# Temp9am           -0.028347
# Temp3pm           -0.200515
# RainToday          0.340510
# RainTomorrow       1.000000

# %%
# Heatmap
plt.figure(figsize=(20,12))

sns.heatmap(df.corr(),annot=True)

# %%
plt.pie(df['RainTomorrow'].value_counts().values,
    labels = df['RainTomorrow'].value_counts().index,
    autopct='%1.1f%%')
plt.show()

# %%
df.iloc[:,:].hist(figsize=(15,15))
plt.show()

# %% [markdown]
# # Classification Model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %% [markdown]
# # Split the data into features and target

# %%
# Preprocess the data
x = df.drop(['Date', 'RainTomorrow'], axis=1)
y = df['RainTomorrow']

# %%
# herein we split the data with test size kept as 15%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 40)
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 0    5439
# 1    1722
# Name: RainTomorrow, dtype: int64
# 0    934
# 1    330
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# # LogisticRegression

# %%
model = LogisticRegression(random_state=1)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
y_pred = model.predict(x_test)

# %%
model.fit(x_train, y_train)
log_acc = accuracy_score(y_test, model.predict(x_test)) 
print("Train Set Accuracy:"+str(accuracy_score(y_train, model.predict(x_train))*100)) 
print("Test Set Accuracy:"+str(accuracy_score(y_test, model.predict(x_test))*100)) 

plt.figure(figsize = (6,4)) 
df_ = pd.DataFrame(confusion_matrix(y_test, model.predict(x_test)), range(2),range(2))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_, annot=True,annot_kws={"size": 16}, fmt='g')
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
# Out:
# Train Set Accuracy:82.642089093702
# Test Set Accuracy:81.25

# %% [markdown]
# # Decision Tree

# %%
dec = DecisionTreeClassifier()
dec.fit(x_train, y_train)

dec_acc = accuracy_score(y_test, dec.predict(x_test))
print("Train test Accuracy:"+str(accuracy_score(y_train, dec.predict(x_train))*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test, dec.predict(x_test))*100))

plt.figure(figsize = (6,4)) 
df_ = pd.DataFrame(confusion_matrix(y_test, dec.predict(x_test)), range(2),range(2))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_, annot=True,annot_kws={"size": 16}, fmt='g')
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
# Out:
# Train test Accuracy:100.0
# Test Set Accuracy:84.41455696202532

# %% [markdown]
# # Random Forest

# %%
r_for = RandomForestClassifier()
r_for.fit(x_train,y_train)

r_acc=accuracy_score(y_test,r_for.predict(x_test))

print("Train Set Accuracy:"+str(accuracy_score(y_train,r_for.predict(x_train))*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test,r_for.predict(x_test))*100))

plt.figure(figsize=(6,4))
df_ = pd.DataFrame(confusion_matrix(y_test, r_for.predict(x_test)), range(2),range(2))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_, annot=True,annot_kws={"size": 16}, fmt='g')
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
# Out:
# Train Set Accuracy:99.98603546990644
# Test Set Accuracy:88.84493670886076

# %% [markdown]
# # KNN - K Nearest Neighbours

# %%
k_nei = KNeighborsClassifier()
k_nei.fit(x_train,y_train)

k_acc = accuracy_score(y_test,k_nei.predict(x_test))

print("Train set Accuracy:"+str(accuracy_score(y_train,k_nei.predict(x_train))*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test,k_nei.predict(x_test))*100))

plt.figure(figsize=(6,4))
df_ = pd.DataFrame(confusion_matrix(y_test, k_nei.predict(x_test)), range(2),range(2))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_, annot=True,annot_kws={"size": 16}, fmt='g')
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
# Out:
# Train set Accuracy:87.3900293255132
# Test Set Accuracy:81.56645569620254

# %% [markdown]
# # SVC

# %%
s_vec = SVC()
s_vec.fit(x_train,y_train)

s_acc = accuracy_score(y_test,s_vec.predict(x_test))

print("Train set Accuracy:"+str(accuracy_score(y_train,s_vec.predict(x_train))*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test,s_vec.predict(x_test))*100))

plt.figure(figsize=(6,4))
df_ = pd.DataFrame(confusion_matrix(y_test, s_vec.predict(x_test)), range(2),range(2))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_, annot=True,annot_kws={"size": 16}, fmt='g')
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
# Out:
# Train set Accuracy:76.09272447982124
# Test Set Accuracy:73.89240506329115

# %% [markdown]
# # Comparing the models and checking the best accuracy

# %%
models = pd.DataFrame({'Model': ['Logistic', 'KNN', 'SVC', 'Decision Tree Classifier',
                       'Random Forest Classifier'],
                       'Accuracy': [ log_acc,k_acc, s_acc, dec_acc, r_acc,]})

models.sort_values(by = 'Accuracy', ascending = False)
# Out:
#                       Model  Accuracy
# 4  Random Forest Classifier  0.888449
# 3  Decision Tree Classifier  0.844146
# 1                       KNN  0.815665
# 0                  Logistic  0.812500
# 2                       SVC  0.738924

# %%
plt.figure(figsize = (16,3))
sns.barplot(x = 'Model', y = 'Accuracy', data = models)
plt.show()

"""We notice here that Random Forest Classifier is giving us the best accuracy result
 so ,we will go with the Random Forest Classifier"""
# Out:
# 'We notice here that Random Forest Classifier is giving us the best accuracy result\n so ,we will go with the Random Forest Classifier'
